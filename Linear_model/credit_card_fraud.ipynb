# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn import metrics
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Load the dataset

# %%
path='./creditcard.csv'
#NOTE:the file in this path is a zip file, extract b4 using it.
dataset=read_csv(path)

# %%
dataset.head(20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ## check for null values

# %%
dataset.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %% [markdown]
# ## Find Percentage of Non Fraud transaction Data

# %%
Class=dataset['Class']
count1=0
for i in Class:
    if (i==0):
        count1+=1

percentage1=count1/len(Class)
print("the percentage of non fraud is ",percentage1)
# Out:
# the percentage of non fraud is  0.9982725143693799

# %% [markdown]
# ## Find Percentage of Fraud transaction Data

# %%
lass=dataset['Class']
count2=0
for i in Class:
    if (i==1):
        count2+=1

percentage2=count2/len(Class)
print("the percentage of non fraud is ",percentage2)
# Out:
# the percentage of non fraud is  0.001727485630620034

# %% [markdown]
# ## Plotting the relation between Time and amount

# %%
x=dataset['Time']

y=dataset['Amount']

plt.plot(x, y) 

plt.title('Time Vs amount')
# Out:
# Text(0.5, 1.0, 'Time Vs amount')

# %% [markdown]
# ## Plot to see Amount Distribution

# %%
plt.figure(figsize=(10,8), )

plt.title('Amount Distribution')

sns.distplot(dataset['Amount'],color='red');
# Out:
# C:\Users\Betina Kuriakose\AppData\Local\Temp\ipykernel_23204\2013568087.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Amount'],color='red');

# %% [markdown]
# ## Correlation between all attribute

# %%
correlation_metrics = dataset.corr() 

fig = plt.figure(figsize = (4, 4)) 

sns.heatmap(correlation_metrics, vmax = .9, square = True) 

plt.show()

# %% [markdown]
# ## to see which range of amount is most frequently used

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(dataset['Amount'], color='red', kde=True)
plt.xscale('log')  # log scale to spread out small values
plt.title('Log-Scaled Amount Distribution')
plt.xlabel('Transaction Amount (log scale)')
plt.ylabel('Density')
plt.show()

# %%
linear =LinearRegression()

# %%
x=dataset.drop(['Class'],axis=1)

# %%
y=dataset['Class']

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
linear=LinearRegression()
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(xtest)

table= pd.DataFrame({"Actual":ytest,"Predicted":y_pred})

table
# Out:
#         Actual  Predicted
# 43428        1   1.218185
# 49906        0  -0.000578
# 29474        0  -0.000726
# 276481       0   0.002957
# 278846       0  -0.001548
# ...        ...        ...
# 75723        0  -0.004392
# 252263       0  -0.000725
# 221246       0   0.001325
# 81910        0   0.001081
# 59490        0   0.005022
#
# [56962 rows x 2 columns]
