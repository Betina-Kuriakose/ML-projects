# %% [markdown]
# ### work on the data

# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
x,y = mglearn.datasets.make_wave(n_samples=40)
print("x[:5]:{}".format(x[:5]))
print("y[:5]:{}".format(y[:5]))
# Out:
# x[:5]:[[-0.75275929]
#  [ 2.70428584]
#  [ 1.39196365]
#  [ 0.59195091]
#  [-2.06388816]]
# y[:5]:[-0.44822073  0.33122576  0.77932073  0.03497884 -1.38773632]

# %%
print("X.shape:{}".format(x.shape))
print("y.shape:{}".format(y.shape))
# Out:
# X.shape:(40, 1)
# y.shape:(40,)

# %%
plt.plot(x,y,'o')
plt.ylim(-3,3)
plt.xlabel("Feature")
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
clf=KNeighborsRegressor(n_neighbors=3)
clf.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print("the prediction are:{}".format(clf.predict(X_test)))
predictions = clf.predict(X_test)
# Out:
# the prediction are:[-0.05396539  0.35686046  1.13671923 -1.89415682 -1.13881398 -1.63113382
#   0.35686046  0.91241374 -0.44680446 -1.13881398]

# %%
print("the test score is:{}".format(clf.score(X_test,y_test)))
print("the train score is:{}".format(clf.score(X_train,y_train)))
# Out:
# the test score is:0.8344172446249605
# the train score is:0.8194343929538755

# %%
import numpy as np

# %%
fig,axes = plt.subplots(1,3,figsize=(15,4))
line = np.linspace(-3,3,1000).reshape(-1,1)
for n_neighbors,ax in zip([1,3,9],axes):
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train,y_train)
    ax.plot(line,reg.predict(line))
    ax.plot(X_train,y_train,'^',c=mglearn.cm2(0),markersize=8)
    ax.plot(X_test,y_test,'v',c=mglearn.cm2(1),markersize=8)
    ax.set_title("{} neighbor(s)\n train score:{:.2f} test score:{:.2f}".format(n_neighbors,reg.score(X_train,y_train),reg.score(X_test,y_test)))
    ax.set_xlabel("Feature")
    ax.set_ylabel("Target")
axes[0].legend(["Model predictions","Training data/target","Test data/target"],loc="best")

# %% [markdown]
# ### the above figure shows overfitting genernal fit underfiting
